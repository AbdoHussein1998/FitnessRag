# %%
from datasets import load_dataset
# Out:
# /mnt/d/learn/life_project/dc_rag/lx_app/lib/python3.10/site-packages/numpy/_core/getlimits.py:551: UserWarning: Signature b'\x00\xd0\xcc\xcc\xcc\xcc\xcc\xcc\xfb\xbf\x00\x00\x00\x00\x00\x00' for <class 'numpy.longdouble'> does not match any known type: falling back to type probe function.
# This warnings indicates broken support for the dtype!
#   machar = _get_machar(dtype)

# %%
from datasets import load_dataset

# Load the dataset
dataset = load_dataset("joey234/mmlu-nutrition-neg-prepend-verbal")
df = dataset["test"].to_pandas()
df["answer/text"]=df.apply(lambda row:row["choices"][row["answer"]],axis=1)
df=df[["question","answer/text"]]

# %%
dataset = load_dataset("joey234/mmlu-nutrition-original-neg")
df = dataset["test"].to_pandas()
df["answer/text"]=df.apply(lambda row:row["choices"][row["answer"]],axis=1)
df=df[["question","answer/text"]]
df
# Out:
#                                              question  \
# 0   Which of the following does not occur with inc...
# 1   Intestinal lactase deficiency leads to lactose...
# 2   Which of the treatments below has not demonstr...
# 3   Bariatric surgery is used for obesity treatmen...
# 4   Which of the following foods do not contain fr...
# 5   What characteristic is not representative of a...
# 6    Which of the following statements is not true?\n
# 7   Observational epidemiology studies have produc...
# 8             What is the density of fat free mass?\n
# 9   It is possible to reduce (though not eliminate...
# 10  Which of the factors below is NOT considered a...
# 11  Which of the following is not a function of vi...
# 12  Which of the following amino acids cannot prov...
# 13  What nutritional strategies will not improve p...
# 14  Which of the following is not a reason for inc...
# 15  Which of the following is not considered a dia...
# ...

# %%
dataset = load_dataset("sarthak-wiz01/nutrition_dataset")
df = dataset["train"].to_pandas()
df
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
#     Age  Gender Height Weight     Activity Level Fitness Goal  \
# 0    25    Male    180     80  Moderately Active  Weight Loss
# 1    32  Female    165     65     Lightly Active  Weight Loss
# 2    48    Male    175     95          Sedentary  Maintenance
# 3    55  Female    160     70        Very Active  Weight Loss
# 4    62    Male    170     85          Sedentary  Maintenance
# ..   ..     ...    ...    ...                ...          ...
# 495  19    Male    183     78     Lightly Active  Weight Loss
# 496  25    Male    180     85  Moderately Active  Weight Loss
# 497  32  Female    165     60     Lightly Active  Muscle Gain
# 498  55    Male    175     90          Sedentary  Weight Loss
# 499  68  Female    160     70          Sedentary  Maintenance
#
#     Dietary Preference Daily Calorie Target Protein Carbohydrates Fat  \
# 0             Omnivore                 2000     120           250  60
# ...

# %%
dataset = load_dataset("saki007ster/nutrition_dataset_mlx_lm")
df=dataset["train"].to_pandas()

# %%
dataset = load_dataset("khanh123456/nutrition")
df=dataset["train"].to_pandas()
df
# Out:
#                                            instruction  input  \
# 0       Nguồn thực phẩm chứa nhiều carbohydrate là gì?    NaN
# 1                  Thực phẩm, đồ ăn chứa carbonhydrate    NaN
# 2                  Nguồn thực phẩm giàu protein là gì?    NaN
# 3                        Thực phẩm, đồ ăn chứa protein    NaN
# 4             Nguồn thực phẩm cung cấp chất béo là gì?    NaN
# ..                                                 ...    ...
# 202  Bổ sung chất xơ và probiotic đã cải thiện tiêu...    NaN
# 203  Tôi đã thấy giảm căng thẳng nhờ bổ sung magiê ...    NaN
# 204  Bổ sung vitamin B12 và folate đã giúp tôi cải ...    NaN
# 205  Tôi đã thấy lợi ích cho hệ miễn dịch khi bổ su...    NaN
# 206  Bổ sung chất béo không bão hòa và chất chống o...    NaN
#
#                                                 output
# 0    Ngũ cốc nguyên hạt (như gạo lứt, yến mạch, qui...
# 1    Ngũ cốc nguyên hạt (như gạo lứt, yến mạch, qui...
# ...

# %%
from DataBase.GoogleSheet import Questions

# %%
qdf=Questions().get_questions()
# Out:
# No header specified. Using default column names.
