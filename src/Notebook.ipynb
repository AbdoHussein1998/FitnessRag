# %%
from pymongo import MongoClient
from qdrant_client import AsyncQdrantClient
client=AsyncQdrantClient(
            api_key="kJ8mN3pQ5rS7tV9wX2yA4bC6dE8fG0hI1jK3lM5nO7pQ9r",
            url="http://localhost:6333"
        )
await client.get_collections()
# Out:
# C:\Users\Allah_Love\AppData\Local\Temp\ipykernel_19480\248698219.py:3: UserWarning: Api key is used with an insecure connection.
#   client=AsyncQdrantClient(
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[8], line 7
#       2 from qdrant_client import AsyncQdrantClient
#       3 client=AsyncQdrantClient(
#       4             api_key="kJ8mN3pQ5rS7tV9wX2yA4bC6dE8fG0hI1jK3lM5nO7pQ9r",
#       5             url="http://localhost:6333"
#       6         )
# ----> 7 await client.get_collections()
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\async_qdrant_client.py:2138, in AsyncQdrantClient.get_collections(self, **kwargs)
#    2132 """Get list name of all existing collections
#    2133
#    2134 Returns:
#    2135     List of the collections
#    2136 """
#    2137 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2138 return await self._client.get_collections(**kwargs)
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\async_qdrant_remote.py:2319, in AsyncQdrantRemote.get_collections(self, **kwargs)
#    2307     response = (
#    2308         await self.grpc_collections.List(
#    2309             grpc.ListCollectionsRequest(), timeout=self._timeout
#    2310         )
#    2311     ).collections
#    2312     return types.CollectionsResponse(
#    2313         collections=[
#    2314             GrpcToRest.convert_collection_description(description)
#    2315             for description in response
#    2316         ]
#    2317     )
#    2318 result: Optional[types.CollectionsResponse] = (
# -> 2319     await self.http.collections_api.get_collections()
#    2320 ).result
#    2321 assert result is not None, "Get collections returned None"
#    2322 return result
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\http\api\collections_api.py:255, in AsyncCollectionsApi.get_collections(self)
#     249 async def get_collections(
#     250     self,
#     251 ) -> m.InlineResponse2004:
#     252     """
#     253     Get list name of all existing collections
#     254     """
# --> 255     return await self._build_for_get_collections()
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\http\api_client.py:184, in AsyncApiClient.request(self, type_, method, url, path_params, **kwargs)
#     182 url = urljoin(host, url.format(**path_params))
#     183 request = self._async_client.build_request(method, url, **kwargs)
# --> 184 return await self.send(request, type_)
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\http\api_client.py:219, in AsyncApiClient.send(self, request, type_)
#     217     except ValidationError as e:
#     218         raise ResponseHandlingException(e)
# --> 219 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 401 (Unauthorized)
# Raw response content:
# b'Invalid API key or JWT'

# %%
# Out:
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 await client.get_collections()
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\async_qdrant_client.py:2138, in AsyncQdrantClient.get_collections(self, **kwargs)
#    2132 """Get list name of all existing collections
#    2133
#    2134 Returns:
#    2135     List of the collections
#    2136 """
#    2137 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 2138 return await self._client.get_collections(**kwargs)
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\async_qdrant_remote.py:2319, in AsyncQdrantRemote.get_collections(self, **kwargs)
#    2307     response = (
#    2308         await self.grpc_collections.List(
#    2309             grpc.ListCollectionsRequest(), timeout=self._timeout
#    2310         )
#    2311     ).collections
#    2312     return types.CollectionsResponse(
#    2313         collections=[
#    2314             GrpcToRest.convert_collection_description(description)
#    2315             for description in response
#    2316         ]
#    2317     )
#    2318 result: Optional[types.CollectionsResponse] = (
# -> 2319     await self.http.collections_api.get_collections()
#    2320 ).result
#    2321 assert result is not None, "Get collections returned None"
#    2322 return result
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\http\api\collections_api.py:255, in AsyncCollectionsApi.get_collections(self)
#     249 async def get_collections(
#     250     self,
#     251 ) -> m.InlineResponse2004:
#     252     """
#     253     Get list name of all existing collections
#     254     """
# --> 255     return await self._build_for_get_collections()
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\http\api_client.py:184, in AsyncApiClient.request(self, type_, method, url, path_params, **kwargs)
#     182 url = urljoin(host, url.format(**path_params))
#     183 request = self._async_client.build_request(method, url, **kwargs)
# --> 184 return await self.send(request, type_)
#
# File d:\Work\Learn\FitnessRag\.venv\lib\site-packages\qdrant_client\http\api_client.py:219, in AsyncApiClient.send(self, request, type_)
#     217     except ValidationError as e:
#     218         raise ResponseHandlingException(e)
# --> 219 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 401 (Unauthorized)
# Raw response content:
# b'Invalid API key or JWT'
